# %%
import os
from IPython.display import Image, display

# %%
base_path = os.getcwd()

# %% [markdown]
# ## Question: How does the model behaves below, at and after the bifurcation point?

# %% [markdown]
# ** Hypothesis:**
# Only at the bifurcation point will the model show the ability to reach the targeted mean activity
#
# The figures below show the mean activity of the model as a function of the target and alpha.
#
# **Figure Legend**:
# Each figure shows the parameter search for a different G (global coupling value)
#
# | Test n     | G   | Bifurcation |
# | ---------- |: --:|-------------|
# | 4          | .198| at the bifurcation point|
# | 5          | .09 |below the bifurcation point|
# | 6          | .01 |below the bifurcation point |
# | 7          | .3  |after the bifurcation point |

# %%
w = Image(os.path.join(base_path, 'data', 'heatmap_testn_4.png'))
z = Image(os.path.join(base_path, 'data', 'heatmap_testn_5.png'))
y = Image(os.path.join(base_path, 'data', 'heatmap_testn_6.png'))
x = Image(os.path.join(base_path, 'data', 'heatmap_testn_7.png'))


display (z, y, x)
